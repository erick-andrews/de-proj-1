# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 100)

# %%
exp = pd.read_csv("~/projects/de-proj-1/op-db/airbnb.csv")

# %%
print(pd.unique(exp['City']))
print(len(pd.unique(exp['Host since'])))
print(pd.unique(exp['Date of scraping']))
# Out:
# ['Firenze' 'Milano' 'Napoli' 'Roma' 'Venezia']
# 5074
# ['2024-12-15' '2024-03-15' '2024-06-15' '2024-09-15']

# %%
exp.head(100)
# Out:
#     Listings id  Last year reviews  Host since Host is superhost  \
# 0         31840                  6  2011-02-07              Host
# 1        222527                  0  2011-07-11         Superhost
# 2         32120                  6  2010-03-26              Host
# 3        224562                  9  2011-09-16              Host
# 4         32180                 11  2014-04-05         Superhost
# 5        224669                 17  2011-09-16         Superhost
# 6         32395                 80  2010-06-07              Host
# 7        227059                 67  2011-09-20         Superhost
# 8         39115                 13  2010-07-15              Host
# 9        230853                 53  2011-09-25         Superhost
# 10        39165                  6  2010-07-15              Host
# 11        39822                  1  2010-06-29              Host
# 12       238351                 14  2011-07-25         Superhost
# 13        43369                  1  2012-11-15              Host
# 14        44781                 32  2009-08-22         Superhost
# 15        45606                 22  2010-08-16              Host
# 16       240985                 63  2011-06-09         Superhost
# 17       248623                 11  2011-10-17              Host
# 18        46520                  7  2011-02-07              Host
# 19        46523                 17  2011-02-07              Host
# 20        46524                 21  2011-02-07              Host
# 21        47498                 11  2010-08-28         Superhost
# 22       249512                  1  2011-09-29              Host
# 23        48372                 12  2010-07-15              Host
# 24        52543                 16  2010-08-16              Host
# 25        52545                  4  2010-08-16              Host
# 26        57542                 14  2010-10-29         Superhost
# 27       250470                 17  2011-10-19         Superhost
# 28        57644                 13  2010-10-30         Superhost
# 29        57767                 22  2010-10-30         Superhost
# 30        57859                 17  2010-10-29         Superhost
# 31        60838                 17  2010-11-21         Superhost
# 32       251811                 23  2010-10-29         Superhost
# 33        64023                 29  2010-03-21              Host
# 34       255154                 15  2011-10-27              Host
# 35        66045                  0  2010-12-20         Superhost
# 36       261609                  1  2011-11-05         Superhost
# 37        66353                  8  2010-12-20         Superhost
# 38        66598                 11  2010-12-20         Superhost
# 39        66903                 13  2010-12-28         Superhost
# 40       264971                  0  2011-11-09              Host
# 41       270205                 19  2011-11-16         Superhost
# 42        67725                  0  2010-07-15              Host
# 43        68273                  0  2011-01-07              Host
# 44        70885                  6  2010-07-15              Host
# 45        71605                  3  2010-07-15              Host
# 46        73345                 23  2011-02-08         Superhost
# 47        73739                  2  2011-02-10         Superhost
# 48       271153                 44  2010-10-18              Host
# 49        74682                 74  2011-02-10              Host
# 50        77570                 97  2011-03-01         Superhost
# 51       273691                 23  2011-06-21              Host
# 52        80692                  0  2012-11-15              Host
# 53        80693                  0  2012-11-15              Host
# 54        80694                  2  2012-11-15              Host
# 55       279009                 40  2009-10-15         Superhost
# 56       279656                 14  2010-10-29         Superhost
# 57        82626                  1  2010-07-15              Host
# 58        83045                 21  2011-02-23              Host
# 59       281491                 24  2011-12-03              Host
# 60       296113                 57  2011-12-22         Superhost
# 61       297891                 14  2010-06-29              Host
# 62        83281                 42  2011-03-21         Superhost
# 63        84726                 13  2010-06-29              Host
# 64       298143                 41  2011-09-20         Superhost
# 65        84829                 25  2011-03-26         Superhost
# 66        89856                 26  2011-04-06              Host
# 67        90557                 25  2011-04-07         Superhost
# 68        94913                 80  2011-04-13              Host
# 69       105652                  0  2013-02-10              Host
# 70       106407                  3  2012-11-15              Host
# 71       109302                 15  2011-05-07              Host
# 72       316854                 14  2012-01-19              Host
# 73       316984                  1  2010-07-15              Host
# 74       122324                  8  2011-05-22         Superhost
# 75       124134                 19  2011-05-23              Host
# 76       339138                  0  2011-08-31              Host
# 77       128095                  1  2011-05-27              Host
# 78       341907                  0  2012-02-11              Host
# 79       129927                  0  2011-05-29              Host
# 80       343773                 46  2012-02-13         Superhost
# 81       132401                 62  2011-06-01         Superhost
# 82       345815                  0  2012-02-15              Host
# 83       132955                  0  2011-06-01              Host
# 84       133197                 71  2011-06-01         Superhost
# 85       346237                  4  2012-02-15              Host
# 86       133411                  7  2010-07-15              Host
# 87       136910                  9  2011-06-06         Superhost
# 88       346238                  3  2012-02-15              Host
# 89       346239                  1  2012-02-15              Host
# 90       138936                  5  2011-04-21              Host
# 91       347062                  2  2012-02-16              Host
# 92       141661                  7  2011-06-11         Superhost
# 93       347729                  0  2011-06-22              Host
# 94       142389                  0  2012-11-15              Host
# 95       142416                  0  2012-11-15              Host
# 96       146732                  0  2011-06-16              Host
# 97       351439                 51  2012-02-20         Superhost
# 98       354097                 31  2012-02-22         Superhost
# 99       354112                  6  2012-02-22         Superhost
#
#     Host number of listings      Neighbourhood  Beds number  Bedrooms number  \
# 0                      44.0     Centro Storico          1.0              1.0
# 1                       3.0            Rifredi          3.0              2.0
# 2                       1.0  Gavinana Galluzzo          1.0              1.0
# 3                       2.0     Centro Storico          1.0              1.0
# 4                       1.0     Centro Storico          4.0              2.0
# 5                       3.0     Campo di Marte          2.0              1.0
# 6                       6.0     Centro Storico          1.0              1.0
# 7                       2.0     Centro Storico          1.0              1.0
# 8                      12.0     Centro Storico          2.0              1.0
# 9                       1.0     Campo di Marte          2.0              1.0
# 10                     12.0     Centro Storico          2.0              1.0
# 11                      5.0     Centro Storico          2.0              1.0
# 12                      6.0     Centro Storico          1.0              1.0
# 13                    160.0     Centro Storico          1.0              1.0
# 14                      3.0     Centro Storico          1.0              1.0
# 15                      4.0   Isolotto Legnaia          4.0              2.0
# 16                      2.0     Centro Storico          1.0              1.0
# 17                      1.0     Centro Storico          2.0              1.0
# 18                     44.0     Centro Storico          2.0              1.0
# 19                     44.0     Centro Storico          1.0              1.0
# 20                     44.0     Centro Storico          2.0              1.0
# 21                      4.0     Centro Storico          1.0              1.0
# 22                      2.0     Campo di Marte          6.0              3.0
# 23                     12.0     Centro Storico          1.0              1.0
# 24                      4.0   Isolotto Legnaia          3.0              2.0
# 25                      4.0   Isolotto Legnaia          2.0              1.0
# 26                     28.0     Centro Storico          1.0              1.0
# 27                      1.0     Centro Storico          2.0              1.0
# 28                      9.0     Centro Storico          3.0              2.0
# 29                      9.0     Centro Storico          3.0              2.0
# 30                     28.0     Centro Storico          1.0              1.0
# 31                      1.0     Centro Storico          2.0              1.0
# 32                     28.0     Centro Storico          6.0              3.0
# 33                      3.0     Centro Storico          1.0              1.0
# 34                      2.0     Campo di Marte          4.0              2.0
# 35                      4.0     Campo di Marte          2.0              1.0
# 36                      6.0     Centro Storico          1.0              1.0
# 37                      4.0     Centro Storico          3.0              2.0
# 38                      4.0     Centro Storico          4.0              2.0
# 39                      1.0     Centro Storico          2.0              1.0
# 40                      2.0     Campo di Marte          1.0              1.0
# 41                      2.0     Centro Storico          1.0              1.0
# 42                     12.0     Centro Storico          2.0              1.0
# 43                      8.0     Centro Storico          1.0              1.0
# 44                     12.0     Centro Storico          2.0              1.0
# 45                     12.0     Centro Storico          2.0              1.0
# 46                      7.0     Centro Storico          2.0              1.0
# 47                      1.0   Isolotto Legnaia          2.0              1.0
# 48                     15.0     Campo di Marte          1.0              1.0
# 49                      1.0     Centro Storico          1.0              1.0
# 50                      3.0     Centro Storico          3.0              2.0
# 51                     14.0     Centro Storico          2.0              1.0
# 52                    160.0     Centro Storico          1.0              1.0
# 53                    160.0     Centro Storico          4.0              2.0
# 54                    160.0     Centro Storico          4.0              2.0
# 55                      1.0     Centro Storico          2.0              1.0
# 56                     28.0     Centro Storico          4.0              2.0
# 57                     12.0     Centro Storico          2.0              1.0
# 58                      3.0     Centro Storico          5.0              3.0
# 59                     11.0     Centro Storico          2.0              1.0
# 60                     12.0     Centro Storico          2.0              1.0
# 61                      5.0     Centro Storico          1.0              1.0
# 62                      1.0     Centro Storico          1.0              1.0
# 63                      5.0     Centro Storico          1.0              1.0
# 64                     48.0     Centro Storico          1.0              1.0
# 65                      2.0     Centro Storico          2.0              1.0
# 66                     44.0     Centro Storico          3.0              2.0
# 67                      4.0     Campo di Marte          3.0              2.0
# 68                     13.0     Centro Storico          2.0              1.0
# 69                      5.0     Centro Storico          7.0              3.0
# 70                    160.0     Centro Storico          7.0              3.0
# 71                      1.0     Centro Storico          1.0              1.0
# 72                      3.0     Campo di Marte          2.0              1.0
# 73                     12.0     Centro Storico          1.0              1.0
# 74                      5.0     Campo di Marte          9.0              4.0
# 75                      3.0   Isolotto Legnaia          4.0              2.0
# 76                     16.0     Campo di Marte          1.0              1.0
# 77                      7.0     Centro Storico          1.0              1.0
# 78                      1.0     Centro Storico          4.0              2.0
# 79                      2.0     Centro Storico          1.0              1.0
# 80                      8.0     Centro Storico          2.0              1.0
# 81                      4.0     Centro Storico          2.0              1.0
# 82                      1.0     Campo di Marte          3.0              2.0
# 83                      6.0     Centro Storico          2.0              1.0
# 84                      1.0     Centro Storico          1.0              1.0
# 85                      5.0     Campo di Marte          3.0              2.0
# 86                     12.0     Centro Storico          2.0              1.0
# 87                      6.0     Centro Storico          1.0              1.0
# 88                      5.0     Campo di Marte          1.0              1.0
# 89                      5.0     Campo di Marte          2.0              1.0
# 90                      1.0     Centro Storico          1.0              1.0
# 91                      5.0   Isolotto Legnaia          7.0              3.0
# 92                      9.0     Centro Storico          8.0              3.0
# 93                      4.0            Rifredi          5.0              3.0
# 94                    160.0     Centro Storico          2.0              1.0
# 95                    160.0     Centro Storico          2.0              1.0
# 96                      2.0     Centro Storico          2.0              1.0
# 97                      4.0     Centro Storico          1.0              1.0
# 98                      7.0     Centro Storico          2.0              1.0
# 99                      7.0     Centro Storico          2.0              1.0
#
#    Property type  Maximum allowed guests   Price  Total reviews  Rating score  \
# 0   Private room                       2    89.0            128          4.65
# 1    Entire home                       4   300.0            284          4.85
# 2    Entire home                       2    95.0             26          4.88
# 3    Entire home                       4    60.0            101          4.66
# 4    Entire home                       4   105.0             34          4.76
# 5    Entire home                       4    86.0             57          5.00
# 6     Hotel room                       2    63.0            682          4.84
# 7   Private room                       2    35.0            461          4.77
# 8   Private room                       2    83.0             76          4.55
# 9   Private room                       2    61.0            549          4.85
# 10  Private room                       2    95.0             20          4.28
# 11   Entire home                       4   121.0             29          4.43
# 12   Entire home                       2   117.0             63          4.81
# 13   Entire home                       2   160.0              8          4.75
# 14   Entire home                       2   159.0            386          4.85
# 15   Entire home                       4    82.0            439          4.75
# 16  Private room                       1    67.0            457          4.84
# 17   Entire home                       4   120.0             91          4.57
# 18  Private room                       3    90.0            102          4.71
# 19  Private room                       1    68.0            258          4.65
# 20  Private room                       3    93.0            108          4.71
# 21  Private room                       3    65.0            521          4.57
# 22   Entire home                      10  1200.0              4          5.00
# 23  Private room                       1    68.0             22          4.52
# 24   Entire home                       5    90.0            214          4.74
# 25   Entire home                       4    66.0            209          4.76
# 26   Entire home                       4   120.0            130          4.49
# 27   Entire home                       4   120.0            149          4.90
# 28   Entire home                       4   106.0            102          4.82
# 29   Entire home                       8   221.0            116          4.91
# 30   Entire home                       3   130.0            199          4.70
# 31   Entire home                       4   126.0            116          4.91
# 32   Entire home                       6   279.0            203          4.78
# 33   Entire home                       2    85.0            196          4.84
# 34   Entire home                       4   129.0            215          4.77
# 35   Entire home                       4    90.0             96          4.64
# 36  Private room                       2    83.0             10          4.38
# 37   Entire home                       5   113.0             31          4.70
# 38   Entire home                       6   133.0            142          4.87
# 39   Entire home                       4   120.0             28          4.93
# 40  Private room                       2  1000.0             80          4.80
# 41   Entire home                       2   120.0            204          4.81
# 42  Private room                       3   114.0              9          4.10
# 43   Entire home                       3   124.0             40          4.98
# 44  Private room                       2    83.0             32          4.38
# 45  Private room                       2    95.0             25          4.21
# 46   Entire home                       4   115.0            153          4.68
# 47   Entire home                       4   105.0             46          4.56
# 48   Entire home                       2    66.0            369          4.48
# 49   Entire home                       2    69.0           1035          4.76
# 50   Entire home                       4   161.0            720          4.93
# 51  Private room                       4    81.0            725          4.81
# 52   Entire home                       4   180.0              2          4.50
# 53   Entire home                       6   257.0             11          4.45
# 54   Entire home                       6   226.0             26          4.32
# 55   Entire home                       2   123.0            323          4.74
# 56   Entire home                       2   187.0             58          4.81
# 57  Private room                       2    83.0             19          4.42
# 58   Entire home                      10   450.0            227          4.70
# 59   Entire home                       3    95.0             72          4.13
# 60   Entire home                       4   110.0            291          4.83
# 61   Entire home                       3    85.0             45          4.64
# 62   Entire home                       2    66.0             46          4.83
# 63   Entire home                       3    99.0            111          4.65
# 64   Entire home                       2   129.0            533          4.78
# 65   Entire home                       4   137.0            133          4.96
# 66   Entire home                       4   179.0            166          4.86
# 67   Entire home                       2    88.0             91          4.85
# 68  Private room                       3   106.0            486          4.74
# 69   Entire home                      10   150.0            408          4.65
# 70   Entire home                      10   415.0             41          4.40
# 71  Private room                       2    75.0            122          4.85
# 72   Entire home                       3    93.0            149          4.92
# 73   Entire home                       2   231.0             28          4.39
# 74   Entire home                      12   826.0             32          4.88
# 75   Entire home                       6   116.0            218          4.62
# 76  Private room                       1    52.0             21          4.85
# 77  Private room                       2   106.0            150          4.75
# 78   Entire home                       4   150.0            229          4.89
# 79   Entire home                       2   160.0            105          4.82
# 80   Entire home                       4   139.0            463          4.98
# 81   Entire home                       3    86.0            269          4.69
# 82   Entire home                       6   100.0              1          5.00
# 83  Private room                       2    40.0             54          4.60
# 84  Private room                       2    79.0            594          4.78
# 85   Entire home                       4   196.0             24          4.63
# 86  Private room                       2    95.0             23          4.61
# 87   Entire home                       1    86.0             77          4.90
# 88   Entire home                       2   159.0             26          4.65
# 89   Entire home                       4   176.0             35          4.80
# 90  Private room                       2    51.0            101          4.75
# 91   Entire home                      10   341.0             14          4.79
# 92   Entire home                       9   254.0             53          4.88
# 93   Entire home                       8   290.0             83          4.78
# 94   Entire home                       4   149.0              1          5.00
# 95   Entire home                       4   256.0             11          4.27
# 96   Entire home                       4   150.0             11          4.73
# 97   Entire home                       4   140.0            219          4.90
# 98   Entire home                       4   176.0            176          4.87
# 99   Entire home                       4   184.0             77          4.89
#
#     Accuracy score  Cleanliness score  Checkin score  Communication score  \
# 0             4.73               4.86           4.85                 4.91
# 1             4.88               4.88           4.99                 4.96
# 2             4.88               4.88           4.84                 4.96
# 3             4.75               4.71           4.76                 4.83
# 4             4.81               4.84           4.81                 4.71
# 5             5.00               5.00           4.98                 4.98
# 6             4.83               4.85           4.90                 4.92
# 7             4.80               4.76           4.89                 4.86
# 8             4.70               4.63           4.83                 4.76
# 9             4.88               4.89           4.93                 4.90
# 10            4.17               4.56           4.67                 4.61
# 11            4.38               4.42           4.69                 4.69
# 12            4.84               4.87           4.92                 4.98
# 13            4.75               4.50           5.00                 4.88
# 14            4.87               4.85           4.92                 4.91
# 15            4.86               4.76           4.91                 4.89
# 16            4.89               4.93           4.93                 4.93
# 17            4.76               4.69           4.68                 4.78
# 18            4.82               4.86           4.96                 4.93
# 19            4.82               4.89           4.86                 4.85
# 20            4.79               4.83           4.89                 4.85
# 21            4.62               4.62           4.88                 4.88
# 22            5.00               5.00           5.00                 5.00
# 23            4.61               4.74           4.74                 4.83
# 24            4.85               4.72           4.89                 4.85
# 25            4.90               4.81           4.91                 4.89
# 26            4.63               4.68           4.56                 4.72
# 27            4.91               4.95           4.95                 4.95
# 28            4.90               4.84           4.93                 4.85
# 29            4.96               4.96           4.89                 4.88
# 30            4.77               4.80           4.76                 4.84
# 31            4.91               4.96           4.97                 5.00
# 32            4.79               4.84           4.82                 4.83
# 33            4.87               4.90           4.96                 4.97
# 34            4.84               4.91           4.89                 4.89
# 35            4.74               4.70           4.93                 4.91
# 36            4.75               4.88           4.50                 5.00
# 37            4.90               4.83           4.93                 4.93
# 38            4.90               4.93           4.94                 4.95
# 39            4.93               4.86           4.96                 5.00
# 40            4.95               4.92           4.82                 4.87
# 41            4.85               4.91           4.96                 4.97
# 42            4.00               4.40           4.70                 4.60
# 43            4.96               5.00           4.88                 5.00
# 44            4.50               4.50           4.69                 4.47
# 45            4.24               4.40           4.64                 4.48
# 46            4.79               4.75           4.76                 4.85
# 47            4.64               4.59           4.41                 4.70
# 48            4.52               4.81           4.74                 4.62
# 49            4.87               4.82           4.84                 4.87
# 50            4.95               4.94           4.99                 4.97
# 51            4.81               4.79           4.91                 4.89
# 52            4.50               4.50           5.00                 5.00
# 53            4.36               4.55           4.00                 4.27
# 54            4.46               4.35           4.65                 4.73
# 55            4.86               4.90           4.82                 4.92
# 56            4.79               4.88           4.79                 4.84
# 57            4.56               4.50           4.72                 4.72
# 58            4.84               4.62           4.82                 4.86
# 59            4.38               4.29           4.36                 4.31
# 60            4.92               4.85           4.92                 4.94
# 61            4.59               4.61           4.86                 4.89
# 62            4.80               4.85           4.96                 4.96
# 63            4.74               4.79           4.82                 4.83
# 64            4.88               4.90           4.94                 4.94
# 65            4.98               4.98           4.98                 4.98
# 66            4.91               4.89           4.93                 4.91
# 67            4.86               4.88           4.90                 4.89
# 68            4.83               4.79           4.86                 4.83
# 69            4.68               4.52           4.86                 4.87
# 70            4.41               4.59           4.49                 4.73
# 71            4.84               4.88           4.91                 4.87
# 72            4.88               4.92           4.94                 4.95
# 73            4.32               4.36           4.82                 4.86
# 74            4.81               4.69           4.91                 4.97
# 75            4.75               4.70           4.89                 4.92
# 76            4.90               4.90           4.95                 4.95
# 77            4.71               4.81           4.92                 4.84
# 78            4.86               4.96           4.97                 4.98
# 79            4.78               4.86           4.79                 4.91
# 80            4.96               4.97           4.99                 4.97
# 81            4.67               4.71           4.79                 4.84
# 82            5.00               5.00           5.00                 5.00
# 83            4.54               4.69           4.80                 4.76
# 84            4.75               4.81           4.91                 4.91
# 85            4.71               4.83           4.83                 4.67
# 86            4.61               4.48           4.78                 4.83
# 87            4.93               4.84           4.93                 4.96
# 88            4.88               4.92           4.85                 4.85
# 89            4.88               4.97           4.97                 5.00
# 90            4.70               4.76           4.91                 4.94
# 91            4.69               4.79           4.93                 4.93
# 92            4.87               4.85           4.92                 4.94
# 93            4.84               4.93           4.84                 4.92
# 94            5.00               5.00           5.00                 4.00
# 95            4.64               4.00           4.55                 5.00
# 96            5.00               4.91           5.00                 5.00
# 97            4.94               4.95           4.91                 4.94
# 98            4.89               4.93           4.98                 4.98
# 99            4.92               4.93           4.95                 4.97
#
#     Location score  Value for money score  Reviews per month     City  \
# 0             4.91                   4.70               0.78  Firenze
# 1             4.60                   4.86               1.92  Firenze
# 2             4.63                   4.63               0.16  Firenze
# 3             4.93                   4.64               0.71  Firenze
# 4             4.81                   4.84               0.21  Firenze
# 5             4.96                   4.98               0.86  Firenze
# 6             4.75                   4.83               4.19  Firenze
# 7             4.98                   4.80               3.45  Firenze
# 8             4.91                   4.56               0.47  Firenze
# 9             4.58                   4.83               3.91  Firenze
# 10            4.94                   4.33               0.13  Firenze
# 11            4.85                   4.42               0.18  Firenze
# 12            4.87                   4.84               0.44  Firenze
# 13            4.88                   4.50               0.07  Firenze
# 14            4.90                   4.83               2.41  Firenze
# 15            4.58                   4.75               2.89  Firenze
# 16            4.91                   4.80               3.08  Firenze
# 17            4.92                   4.69               0.64  Firenze
# 18            4.87                   4.77               0.63  Firenze
# 19            4.81                   4.67               1.61  Firenze
# 20            4.88                   4.72               0.70  Firenze
# 21            4.94                   4.59               3.24  Firenze
# 22            4.75                   5.00               0.05  Firenze
# 23            4.96                   4.57               0.15  Firenze
# 24            4.65                   4.71               1.39  Firenze
# 25            4.72                   4.80               1.41  Firenze
# 26            4.72                   4.48               0.83  Firenze
# 27            4.66                   4.84               1.06  Firenze
# 28            4.96                   4.85               0.68  Firenze
# 29            4.93                   4.89               0.78  Firenze
# 30            4.95                   4.66               1.30  Firenze
# 31            4.90                   4.85               0.75  Firenze
# 32            4.83                   4.75               1.39  Firenze
# 33            4.92                   4.82               1.28  Firenze
# 34            4.54                   4.71               1.68  Firenze
# 35            4.52                   4.60               0.61  Firenze
# 36            4.88                   4.75               0.07  Firenze
# 37            4.86                   4.76               0.20  Firenze
# 38            4.94                   4.86               0.94  Firenze
# 39            5.00                   4.79               0.18  Firenze
# 40            4.46                   4.75               0.55  Firenze
# 41            4.95                   4.77               1.43  Firenze
# 42            4.90                   4.20               0.08  Firenze
# 43            4.92                   4.92               0.26  Firenze
# 44            4.84                   4.25               0.21  Firenze
# 45            4.84                   4.24               0.16  Firenze
# 46            4.95                   4.67               1.65  Firenze
# 47            4.77                   4.50               0.30  Firenze
# 48            4.51                   4.40               2.54  Firenze
# 49            4.90                   4.81               6.70  Firenze
# 50            4.99                   4.92               5.41  Firenze
# 51            4.93                   4.81               4.97  Firenze
# 52            5.00                   4.00               0.02  Firenze
# 53            4.91                   4.27               0.11  Firenze
# 54            5.00                   4.19               0.17  Firenze
# 55            4.85                   4.69               2.35  Firenze
# 56            4.91                   4.79               0.41  Firenze
# 57            4.78                   4.17               0.12  Firenze
# 58            4.90                   4.78               1.64  Firenze
# 59            4.90                   4.22               0.50  Firenze
# 60            4.98                   4.85               2.06  Firenze
# 61            4.98                   4.55               0.31  Firenze
# 62            5.00                   4.76               0.72  Firenze
# 63            4.80                   4.65               0.72  Firenze
# 64            4.94                   4.78               3.74  Firenze
# 65            4.98                   4.92               0.87  Firenze
# 66            4.94                   4.79               1.18  Firenze
# 67            4.85                   4.74               0.78  Firenze
# 68            4.91                   4.79               3.19  Firenze
# 69            4.93                   4.73               2.66  Firenze
# 70            4.85                   4.34               0.27  Firenze
# 71            4.94                   4.86               0.81  Firenze
# 72            4.87                   4.92               1.09  Firenze
# 73            4.89                   4.21               0.22  Firenze
# 74            4.69                   4.75               0.23  Firenze
# 75            4.56                   4.69               1.44  Firenze
# 76            4.65                   4.80               0.15  Firenze
# 77            4.74                   4.76               1.06  Firenze
# 78            4.88                   4.91               1.60  Firenze
# 79            4.96                   4.75               0.70  Firenze
# 80            4.93                   4.97               3.33  Firenze
# 81            4.75                   4.71               1.77  Firenze
# 82            4.00                   4.00               0.01  Firenze
# 83            4.56                   4.50               0.36  Firenze
# 84            4.65                   4.71               3.90  Firenze
# 85            4.79                   4.67               0.30  Firenze
# 86            4.91                   4.61               0.19  Firenze
# 87            4.95                   4.84               0.61  Firenze
# 88            4.46                   4.65               0.29  Firenze
# 89            4.85                   4.82               0.34  Firenze
# 90            4.84                   4.71               0.68  Firenze
# 91            4.86                   4.71               0.11  Firenze
# 92            4.92                   4.85               0.38  Firenze
# 93            4.30                   4.78               0.59  Firenze
# 94            5.00                   4.00               0.01  Firenze
# 95            4.91                   4.45               0.14  Firenze
# 96            4.82                   4.82               0.15  Firenze
# 97            4.98                   4.90               1.54  Firenze
# 98            4.65                   4.81               1.24  Firenze
# 99            4.79                   4.81               0.54  Firenze
#
#           Season  Bathrooms number Bathrooms type  \
# 0   Early Winter                 1        private
# 1   Early Winter                 1        private
# 2   Early Winter                 1        private
# 3   Early Winter                 1        private
# 4   Early Winter                 2        private
# 5   Early Winter                 1        private
# 6   Early Winter                 1        private
# 7   Early Winter                 2         shared
# 8   Early Winter                 0        private
# 9   Early Winter                 1        private
# 10  Early Winter                 1        private
# 11  Early Winter                 1        private
# 12  Early Winter                 1        private
# 13  Early Winter                 1        private
# 14  Early Winter                 1        private
# 15  Early Winter                 1        private
# 16  Early Winter                 1        private
# 17  Early Winter                 1        private
# 18  Early Winter                 1        private
# 19  Early Winter                 1        private
# 20  Early Winter                 1        private
# 21  Early Winter                 2         shared
# 22  Early Winter                 4        private
# 23  Early Winter                 0        private
# 24  Early Winter                 2        private
# 25  Early Winter                 1        private
# 26  Early Winter                 1        private
# 27  Early Winter                 1        private
# 28  Early Winter                 1        private
# 29  Early Winter                 2        private
# 30  Early Winter                 1        private
# 31  Early Winter                 2        private
# 32  Early Winter                 1        private
# 33  Early Winter                 1        private
# 34  Early Winter                 2        private
# 35  Early Winter                 1        private
# 36  Early Winter                 1        private
# 37  Early Winter                 3        private
# 38  Early Winter                 2        private
# 39  Early Winter                 1        private
# 40  Early Winter                 1        private
# 41  Early Winter                 1        private
# 42  Early Winter                 1        private
# 43  Early Winter                 2        private
# 44  Early Winter                 0        private
# 45  Early Winter                 1        private
# 46  Early Winter                 1        private
# 47  Early Winter                 1        private
# 48  Early Winter                 1        private
# 49  Early Winter                 1        private
# 50  Early Winter                 2        private
# 51  Early Winter                 1        private
# 52  Early Winter                 1        private
# 53  Early Winter                 1        private
# 54  Early Winter                 1        private
# 55  Early Winter                 1        private
# 56  Early Winter                 2        private
# 57  Early Winter                 0        private
# 58  Early Winter                 3        private
# 59  Early Winter                 1        private
# 60  Early Winter                 1        private
# 61  Early Winter                 1        private
# 62  Early Winter                 1        private
# 63  Early Winter                 1        private
# 64  Early Winter                 1        private
# 65  Early Winter                 1        private
# 66  Early Winter                 1        private
# 67  Early Winter                 2        private
# 68  Early Winter                 1        private
# 69  Early Winter                 2        private
# 70  Early Winter                 2        private
# 71  Early Winter                 1        private
# 72  Early Winter                 1        private
# 73  Early Winter                 1        private
# 74  Early Winter                 6        private
# 75  Early Winter                 2        private
# 76  Early Winter                 1         shared
# 77  Early Winter                 1        private
# 78  Early Winter                 2        private
# 79  Early Winter                 1        private
# 80  Early Winter                 1        private
# 81  Early Winter                 1        private
# 82  Early Winter                 3        private
# 83  Early Winter                 1        private
# 84  Early Winter                 1        private
# 85  Early Winter                 1        private
# 86  Early Winter                 1        private
# 87  Early Winter                 1        private
# 88  Early Winter                 1        private
# 89  Early Winter                 1        private
# 90  Early Winter                 1        private
# 91  Early Winter                 2        private
# 92  Early Winter                 2        private
# 93  Early Winter                 3        private
# 94  Early Winter                 1        private
# 95  Early Winter                 1        private
# 96  Early Winter                 1        private
# 97  Early Winter                 1        private
# 98  Early Winter                 2        private
# 99  Early Winter                 1        private
#
#                               Coordinates Date of scraping
# 0                      43.77709, 11.25216       2024-12-15
# 1                      43.82005, 11.22004       2024-12-15
# 2                      43.76157, 11.27741       2024-12-15
# 3                        43.772, 11.26142       2024-12-15
# 4                      43.76832, 11.24348       2024-12-15
# 5                       43.76796, 11.2714       2024-12-15
# 6                      43.76268, 11.24149       2024-12-15
# 7                       43.77022, 11.2561       2024-12-15
# 8                      43.77525, 11.25258       2024-12-15
# 9                       43.77388, 11.2844       2024-12-15
# 10                     43.77525, 11.25258       2024-12-15
# 11                     43.76742, 11.24378       2024-12-15
# 12                     43.76914, 11.24193       2024-12-15
# 13                     43.76944, 11.26331       2024-12-15
# 14                     43.76418, 11.24618       2024-12-15
# 15                      43.7728, 11.23746       2024-12-15
# 16                     43.77701, 11.25421       2024-12-15
# 17                       43.7723, 11.2616       2024-12-15
# 18                     43.77699, 11.25216       2024-12-15
# 19                     43.77704, 11.25217       2024-12-15
# 20                       43.777, 11.25216       2024-12-15
# 21                     43.77386, 11.25028       2024-12-15
# 22                     43.76736, 11.27223       2024-12-15
# 23                     43.77525, 11.25258       2024-12-15
# 24                      43.77175, 11.2364       2024-12-15
# 25                     43.77164, 11.23819       2024-12-15
# 26                     43.77236, 11.24787       2024-12-15
# 27                     43.78118, 11.23266       2024-12-15
# 28                     43.77713, 11.26182       2024-12-15
# 29                     43.76728, 11.25066       2024-12-15
# 30                     43.77613, 11.25492       2024-12-15
# 31                     43.77263, 11.26316       2024-12-15
# 32                      43.7733, 11.24754       2024-12-15
# 33                     43.77089, 11.25966       2024-12-15
# 34  43.76813583209722, 11.280788866715431       2024-12-15
# 35                     43.78262, 11.26856       2024-12-15
# 36                     43.77455, 11.23997       2024-12-15
# 37                     43.77055, 11.26723       2024-12-15
# 38                     43.76787, 11.26324       2024-12-15
# 39                     43.77591, 11.25846       2024-12-15
# 40                     43.76999, 11.30511       2024-12-15
# 41                     43.77299, 11.26279       2024-12-15
# 42                     43.77525, 11.25258       2024-12-15
# 43                     43.77931, 11.25805       2024-12-15
# 44                     43.77525, 11.25258       2024-12-15
# 45                     43.77525, 11.25258       2024-12-15
# 46                      43.76971, 11.2518       2024-12-15
# 47                     43.76988, 11.23978       2024-12-15
# 48                     43.78202, 11.32323       2024-12-15
# 49                     43.77243, 11.24519       2024-12-15
# 50                     43.77272, 11.25914       2024-12-15
# 51                     43.77531, 11.25456       2024-12-15
# 52                     43.77556, 11.26009       2024-12-15
# 53                     43.77556, 11.26009       2024-12-15
# 54                     43.77556, 11.26009       2024-12-15
# 55                     43.77326, 11.24596       2024-12-15
# 56                   43.764389, 11.261067       2024-12-15
# 57                     43.77525, 11.25258       2024-12-15
# 58                     43.76807, 11.25997       2024-12-15
# 59                     43.77453, 11.25684       2024-12-15
# 60                       43.7681, 11.2564       2024-12-15
# 61                      43.7689, 11.24409       2024-12-15
# 62                    43.76947, 11.254953       2024-12-15
# 63                     43.76207, 11.24275       2024-12-15
# 64                     43.77203, 11.25575       2024-12-15
# 65                     43.77358, 11.25723       2024-12-15
# 66                     43.76801, 11.26212       2024-12-15
# 67                     43.77017, 11.27702       2024-12-15
# 68                     43.76971, 11.24542       2024-12-15
# 69                      43.77598, 11.2548       2024-12-15
# 70                     43.76977, 11.26376       2024-12-15
# 71                     43.77082, 11.25711       2024-12-15
# 72                     43.79101, 11.29321       2024-12-15
# 73                     43.77525, 11.25259       2024-12-15
# 74  43.80993910508455, 11.273253396410809       2024-12-15
# 75                     43.77423, 11.23028       2024-12-15
# 76                     43.77893, 11.26936       2024-12-15
# 77                     43.77412, 11.24568       2024-12-15
# 78                     43.76957, 11.26455       2024-12-15
# 79    43.77471850305955, 11.2559369778253       2024-12-15
# 80                     43.77427, 11.26205       2024-12-15
# 81                     43.77059, 11.26509       2024-12-15
# 82                     43.81893, 11.28034       2024-12-15
# 83                     43.76035, 11.24044       2024-12-15
# 84                     43.78213, 11.24163       2024-12-15
# 85                     43.77133, 11.31963       2024-12-15
# 86                     43.77533, 11.25254       2024-12-15
# 87                     43.77111, 11.24893       2024-12-15
# 88                     43.77119, 11.31819       2024-12-15
# 89                     43.77149, 11.31847       2024-12-15
# 90                     43.77579, 11.24643       2024-12-15
# 91                     43.77217, 11.23438       2024-12-15
# 92                     43.77255, 11.26408       2024-12-15
# 93                       43.8026, 11.2378       2024-12-15
# 94                     43.76958, 11.26351       2024-12-15
# 95                      43.7702, 11.26215       2024-12-15
# 96                       43.7622, 11.2431       2024-12-15
# 97                     43.76779, 11.25987       2024-12-15
# 98                     43.76196, 11.24245       2024-12-15
# 99                     43.76196, 11.24245       2024-12-15

# %%
len(exp)
# Out:
# 282047

# %%
print(len(pd.unique(exp['Listings id'])))
# Out:
# 92355

# %%
exp[exp["City"] == "Firenze"]
# Out:
#                Listings id  Last year reviews  Host since Host is superhost  \
# 0                    31840                  6  2011-02-07              Host
# 1                   222527                  0  2011-07-11         Superhost
# 2                    32120                  6  2010-03-26              Host
# 3                   224562                  9  2011-09-16              Host
# 4                    32180                 11  2014-04-05         Superhost
# ...                    ...                ...         ...               ...
# 41238  1236248338760723102                  1  2024-09-01              Host
# 41239  1237418137104849814                  2  2019-04-16              Host
# 41240  1238313522110505122                  1  2024-09-04              Host
# 41241  1239066145299909903                  1  2012-05-20              Host
# 41242  1239133798159716723                  1  2015-09-17         Superhost
#
#        Host number of listings      Neighbourhood  Beds number  \
# 0                         44.0     Centro Storico          1.0
# 1                          3.0            Rifredi          3.0
# 2                          1.0  Gavinana Galluzzo          1.0
# 3                          2.0     Centro Storico          1.0
# 4                          1.0     Centro Storico          4.0
# ...                        ...                ...          ...
# 41238                      1.0     Campo di Marte          2.0
# 41239                      5.0     Centro Storico          3.0
# 41240                      1.0     Campo di Marte          1.0
# 41241                      1.0     Centro Storico          1.0
# 41242                     25.0     Centro Storico          2.0
#
#        Bedrooms number Property type  Maximum allowed guests  Price  \
# 0                  1.0  Private room                       2   89.0
# 1                  2.0   Entire home                       4  300.0
# 2                  1.0   Entire home                       2   95.0
# 3                  1.0   Entire home                       4   60.0
# 4                  2.0   Entire home                       4  105.0
# ...                ...           ...                     ...    ...
# 41238              2.0   Entire home                       4  105.0
# 41239              2.0   Entire home                       4  125.0
# 41240              1.0   Entire home                       2   98.0
# 41241              1.0  Private room                       1   94.0
# 41242              1.0   Entire home                       3  144.0
#
#        Total reviews  Rating score  Accuracy score  Cleanliness score  \
# 0                128          4.65            4.73               4.86
# 1                284          4.85            4.88               4.88
# 2                 26          4.88            4.88               4.88
# 3                101          4.66            4.75               4.71
# 4                 34          4.76            4.81               4.84
# ...              ...           ...             ...                ...
# 41238              1          5.00            5.00               5.00
# 41239              2          4.50            4.00               5.00
# 41240              1          5.00            5.00               5.00
# 41241              1          5.00            5.00               5.00
# 41242              1          5.00            5.00               5.00
#
#        Checkin score  Communication score  Location score  \
# 0               4.85                 4.91            4.91
# 1               4.99                 4.96            4.60
# 2               4.84                 4.96            4.63
# 3               4.76                 4.83            4.93
# 4               4.81                 4.71            4.81
# ...              ...                  ...             ...
# 41238           5.00                 5.00            5.00
# 41239           3.50                 3.00            3.00
# 41240           5.00                 5.00            5.00
# 41241           5.00                 5.00            4.00
# 41242           5.00                 5.00            5.00
#
#        Value for money score  Reviews per month     City        Season  \
# 0                       4.70               0.78  Firenze  Early Winter
# 1                       4.86               1.92  Firenze  Early Winter
# 2                       4.63               0.16  Firenze  Early Winter
# 3                       4.64               0.71  Firenze  Early Winter
# 4                       4.84               0.21  Firenze  Early Winter
# ...                      ...                ...      ...           ...
# 41238                   5.00               1.00  Firenze  Early Autumn
# 41239                   3.50               2.00  Firenze  Early Autumn
# 41240                   5.00               1.00  Firenze  Early Autumn
# 41241                   5.00               1.00  Firenze  Early Autumn
# 41242                   5.00               1.00  Firenze  Early Autumn
#
#        Bathrooms number Bathrooms type                            Coordinates  \
# 0                     1        private                     43.77709, 11.25216
# 1                     1        private                     43.82005, 11.22004
# 2                     1        private                     43.76157, 11.27741
# 3                     1        private                       43.772, 11.26142
# 4                     2        private                     43.76832, 11.24348
# ...                 ...            ...                                    ...
# 41238                 1        private                 43.7689407, 11.2797417
# 41239                 1        private    43.7825537562829, 11.23673893236205
# 41240                 1        private                  43.788893, 11.2743626
# 41241                 1         shared  43.78409984948205, 11.230298367350713
# 41242                 1        private  43.75972510764057, 11.240383855102491
#
#       Date of scraping
# 0           2024-12-15
# 1           2024-12-15
# 2           2024-12-15
# 3           2024-12-15
# 4           2024-12-15
# ...                ...
# 41238       2024-09-15
# 41239       2024-09-15
# 41240       2024-09-15
# 41241       2024-09-15
# 41242       2024-09-15
#
# [41243 rows x 26 columns]

# %%
repeated_observations = exp[exp['Listings id'].duplicated(keep=False)]

# %%
repeated_observations
# Out:
#                 Listings id  Last year reviews  Host since Host is superhost  \
# 0                     31840                  6  2011-02-07              Host
# 1                    222527                  0  2011-07-11         Superhost
# 2                     32120                  6  2010-03-26              Host
# 3                    224562                  9  2011-09-16              Host
# 4                     32180                 11  2014-04-05         Superhost
# ...                     ...                ...         ...               ...
# 281725  1164352900011086287                  5  2024-05-25              Host
# 281731  1164391646978617821                  1  2023-07-16              Host
# 281732  1164450228524842186                  2  2023-07-16              Host
# 281761  1167918715222343501                 10  2018-05-11              Host
# 281787  1171144939897438568                  6  2014-09-25         Superhost
#
#         Host number of listings      Neighbourhood  Beds number  \
# 0                          44.0     Centro Storico          1.0
# 1                           3.0            Rifredi          3.0
# 2                           1.0  Gavinana Galluzzo          1.0
# 3                           2.0     Centro Storico          1.0
# 4                           1.0     Centro Storico          4.0
# ...                         ...                ...          ...
# 281725                      6.0         Piave 1860          2.0
# 281731                     21.0           Marghera          2.0
# 281732                     21.0           Marghera          0.0
# 281761                     11.0           Marghera          1.0
# 281787                      1.0          San Marco          0.0
#
#         Bedrooms number Property type  Maximum allowed guests  Price  \
# 0                   1.0  Private room                       2   89.0
# 1                   2.0   Entire home                       4  300.0
# 2                   1.0   Entire home                       2   95.0
# 3                   1.0   Entire home                       4   60.0
# 4                   2.0   Entire home                       4  105.0
# ...                 ...           ...                     ...    ...
# 281725              1.0  Private room                       2   75.0
# 281731              1.0  Private room                       3   71.0
# 281732              1.0  Private room                       2   61.0
# 281761              1.0  Private room                       1   38.0
# 281787              2.0   Entire home                       4  151.0
#
#         Total reviews  Rating score  Accuracy score  Cleanliness score  \
# 0                 128          4.65            4.73               4.86
# 1                 284          4.85            4.88               4.88
# 2                  26          4.88            4.88               4.88
# 3                 101          4.66            4.75               4.71
# 4                  34          4.76            4.81               4.84
# ...               ...           ...             ...                ...
# 281725              5          4.20            4.40               4.20
# 281731              1          4.00            5.00               5.00
# 281732              2          5.00            5.00               5.00
# 281761             10          4.40            4.40               4.40
# 281787              6          5.00            5.00               4.83
#
#         Checkin score  Communication score  Location score  \
# 0                4.85                 4.91            4.91
# 1                4.99                 4.96            4.60
# 2                4.84                 4.96            4.63
# 3                4.76                 4.83            4.93
# 4                4.81                 4.71            4.81
# ...               ...                  ...             ...
# 281725           4.80                 4.00            4.20
# 281731           5.00                 5.00            3.00
# 281732           4.50                 5.00            5.00
# 281761           4.80                 4.80            4.30
# 281787           5.00                 5.00            5.00
#
#         Value for money score  Reviews per month     City        Season  \
# 0                        4.70               0.78  Firenze  Early Winter
# 1                        4.86               1.92  Firenze  Early Winter
# 2                        4.63               0.16  Firenze  Early Winter
# 3                        4.64               0.71  Firenze  Early Winter
# 4                        4.84               0.21  Firenze  Early Winter
# ...                       ...                ...      ...           ...
# 281725                   4.00               1.61  Venezia  Early Autumn
# 281731                   4.00               0.31  Venezia  Early Autumn
# 281732                   5.00               0.61  Venezia  Early Autumn
# 281761                   4.50               3.23  Venezia  Early Autumn
# 281787                   5.00               1.96  Venezia  Early Autumn
#
#         Bathrooms number Bathrooms type  \
# 0                      1        private
# 1                      1        private
# 2                      1        private
# 3                      1        private
# 4                      2        private
# ...                  ...            ...
# 281725                 1        private
# 281731                 1         shared
# 281732                 1         shared
# 281761                 1        private
# 281787                 1        private
#
#                                    Coordinates Date of scraping
# 0                           43.77709, 11.25216       2024-12-15
# 1                           43.82005, 11.22004       2024-12-15
# 2                           43.76157, 11.27741       2024-12-15
# 3                             43.772, 11.26142       2024-12-15
# 4                           43.76832, 11.24348       2024-12-15
# ...                                        ...              ...
# 281725  45.483120705965526, 12.235358752170638       2024-09-15
# 281731                      45.48102, 12.22502       2024-09-15
# 281732                       45.4722, 12.21873       2024-09-15
# 281761                      45.47374, 12.22456       2024-09-15
# 281787   45.43499346488515, 12.336240336298944       2024-09-15
#
# [265358 rows x 26 columns]

# %%
repeated_observations[repeated_observations['Listings id'] == 222527]
# Out:
#        Listings id  Last year reviews  Host since Host is superhost  \
# 1           222527                  0  2011-07-11         Superhost
# 14658       222527                  0  2011-07-11         Superhost
#
#        Host number of listings Neighbourhood  Beds number  Bedrooms number  \
# 1                          3.0       Rifredi          3.0              2.0
# 14658                      3.0       Rifredi          3.0              1.0
#
#       Property type  Maximum allowed guests  Price  Total reviews  \
# 1       Entire home                       4  300.0            284
# 14658   Entire home                       4  300.0            284
#
#        Rating score  Accuracy score  Cleanliness score  Checkin score  \
# 1              4.85            4.88               4.88           4.99
# 14658          4.85            4.88               4.88           4.99
#
#        Communication score  Location score  Value for money score  \
# 1                     4.96             4.6                   4.86
# 14658                 4.96             4.6                   4.86
#
#        Reviews per month     City        Season  Bathrooms number  \
# 1                   1.92  Firenze  Early Winter                 1
# 14658               1.88  Firenze  Early Spring                 1
#
#       Bathrooms type         Coordinates Date of scraping
# 1            private  43.82005, 11.22004       2024-12-15
# 14658        private  43.82005, 11.22004       2024-03-15

# %%
from shapely.geometry import Point

def to_wkt(coord):
    lat, lon = map(float, coord.split(','))
    return Point(lon, lat).wkt  # Note: WKT format is (lon lat)

exp['Coordinates'] = exp['Coordinates'].apply(to_wkt)

# %%
column_mapping = {
    'Listings id': 'listing_id',
    'Last year reviews': 'last_year_reviews',
    'Host since': 'host_since',
    'Host is superhost': 'host_is_superhost',
    'Host number of listings': 'host_number_of_listings',
    'Neighbourhood': 'neighbourhood',
    'Beds number': 'beds_number',
    'Bedrooms number': 'bedrooms_number',
    'Property type': 'property_type',
    'Maximum allowed guests': 'max_allowed_guests',
    'Price': 'price',
    'Total reviews': 'total_reviews',
    'Rating score': 'rating_score',
    'Accuracy score': 'accuracy_score',
    'Cleanliness score': 'cleanliness_score',
    'Checkin score': 'checkin_score',
    'Communication score': 'communication_score',
    'Location score': 'location_score',
    'Value for money score': 'value_for_money_score',
    'Reviews per month': 'reviews_per_month',
    'City': 'city',
    'Season': 'season',
    'Bathrooms number': 'bathrooms_number',
    'Bathrooms type': 'bathrooms_type',
    'Coordinates': 'coordinates',
    'Date of scraping': 'date_of_scraping'
}

# Rename the columns
exp = exp.rename(columns=column_mapping)

# Reorder the columns to match the staging table
staging_columns = [
    'listing_id',
    'last_year_reviews',
    'host_since',
    'host_is_superhost',
    'host_number_of_listings',
    'neighbourhood',
    'beds_number',
    'bedrooms_number',
    'property_type',
    'max_allowed_guests',
    'price',
    'total_reviews',
    'rating_score',
    'accuracy_score',
    'cleanliness_score',
    'checkin_score',
    'communication_score',
    'location_score',
    'value_for_money_score',
    'reviews_per_month',
    'city',
    'season',
    'bathrooms_number',
    'bathrooms_type',
    'coordinates',
    'date_of_scraping'
]

# Select and reorder the columns
exp = exp[staging_columns]

# %%
exp['host_is_superhost'] = exp['host_is_superhost'].map({'Superhost': True, 'Host': False})
exp
# Out:
#                  listing_id  last_year_reviews  host_since  host_is_superhost  \
# 0                     31840                  6  2011-02-07              False
# 1                    222527                  0  2011-07-11               True
# 2                     32120                  6  2010-03-26              False
# 3                    224562                  9  2011-09-16              False
# 4                     32180                 11  2014-04-05               True
# ...                     ...                ...         ...                ...
# 282042  1225415779557432758                  1  2023-07-09              False
# 282043  1226565187491241376                  1  2016-09-09              False
# 282044  1227320704279156110                  1  2022-03-06              False
# 282045  1227366399659654882                  1  2024-04-26              False
# 282046  1228931183480447079                  1  2014-07-05              False
#
#         host_number_of_listings           neighbourhood  beds_number  \
# 0                          44.0          Centro Storico          1.0
# 1                           3.0                 Rifredi          3.0
# 2                           1.0       Gavinana Galluzzo          1.0
# 3                           2.0          Centro Storico          1.0
# 4                           1.0          Centro Storico          4.0
# ...                         ...                     ...          ...
# 282042                      3.0             Santa Croce          3.0
# 282043                      1.0               Dorsoduro          1.0
# 282044                      6.0              Piave 1860          3.0
# 282045                     14.0  San Lorenzo XXV Aprile          2.0
# 282046                     11.0              Cannaregio          1.0
#
#         bedrooms_number property_type  max_allowed_guests  price  \
# 0                   1.0  Private room                   2   89.0
# 1                   2.0   Entire home                   4  300.0
# 2                   1.0   Entire home                   2   95.0
# 3                   1.0   Entire home                   4   60.0
# 4                   2.0   Entire home                   4  105.0
# ...                 ...           ...                 ...    ...
# 282042              2.0   Entire home                   4  120.0
# 282043              1.0   Entire home                   2  173.0
# 282044              3.0   Entire home                   5  125.0
# 282045              1.0   Entire home                   4  132.0
# 282046              1.0   Entire home                   2  211.0
#
#         total_reviews  rating_score  accuracy_score  cleanliness_score  \
# 0                 128          4.65            4.73               4.86
# 1                 284          4.85            4.88               4.88
# 2                  26          4.88            4.88               4.88
# 3                 101          4.66            4.75               4.71
# 4                  34          4.76            4.81               4.84
# ...               ...           ...             ...                ...
# 282042              1          1.00            1.00               2.00
# 282043              1          5.00            5.00               5.00
# 282044              1          3.00            3.00               4.00
# 282045              1          5.00            5.00               5.00
# 282046              1          5.00            5.00               5.00
#
#         checkin_score  communication_score  location_score  \
# 0                4.85                 4.91            4.91
# 1                4.99                 4.96            4.60
# 2                4.84                 4.96            4.63
# 3                4.76                 4.83            4.93
# 4                4.81                 4.71            4.81
# ...               ...                  ...             ...
# 282042           1.00                 2.00            5.00
# 282043           5.00                 5.00            5.00
# 282044           2.00                 1.00            3.00
# 282045           5.00                 5.00            5.00
# 282046           5.00                 5.00            5.00
#
#         value_for_money_score  reviews_per_month     city        season  \
# 0                        4.70               0.78  Firenze  Early Winter
# 1                        4.86               1.92  Firenze  Early Winter
# 2                        4.63               0.16  Firenze  Early Winter
# 3                        4.64               0.71  Firenze  Early Winter
# 4                        4.84               0.21  Firenze  Early Winter
# ...                       ...                ...      ...           ...
# 282042                   1.00               1.00  Venezia  Early Autumn
# 282043                   5.00               1.00  Venezia  Early Autumn
# 282044                   2.00               1.00  Venezia  Early Autumn
# 282045                   5.00               1.00  Venezia  Early Autumn
# 282046                   4.00               1.00  Venezia  Early Autumn
#
#         bathrooms_number bathrooms_type  \
# 0                      1        private
# 1                      1        private
# 2                      1        private
# 3                      1        private
# 4                      2        private
# ...                  ...            ...
# 282042                 1        private
# 282043                 1        private
# 282044                 1        private
# 282045                 1        private
# 282046                 1        private
#
#                                          coordinates date_of_scraping
# 0                          POINT (11.25216 43.77709)       2024-12-15
# 1                          POINT (11.22004 43.82005)       2024-12-15
# 2                          POINT (11.27741 43.76157)       2024-12-15
# 3                            POINT (11.26142 43.772)       2024-12-15
# 4                          POINT (11.24348 43.76832)       2024-12-15
# ...                                              ...              ...
# 282042                     POINT (12.32484 45.44175)       2024-09-15
# 282043    POINT (12.3209960013628 45.43524874231471)       2024-09-15
# 282044                 POINT (12.2292505 45.4859248)       2024-09-15
# 282045  POINT (12.244685252349434 45.49259973446829)       2024-09-15
# 282046  POINT (12.338529692358108 45.43932359710468)       2024-09-15
#
# [282047 rows x 26 columns]

# %%
exp.to_csv("/home/eandrews/projects/de-proj-1/op-db/airbnb_clean.csv", index=False)

# %%
len(exp.columns)
# Out:
# 26
